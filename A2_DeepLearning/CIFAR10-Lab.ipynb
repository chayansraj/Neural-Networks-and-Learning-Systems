# %%
import os
import tensorflow as tf

# If there are multiple GPUs and we only want to use one/some, set the number in the visible device list.
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# This sets the GPU to allocate memory only as needed
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) != 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# 2022-02-15 10:37:56.436737: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-02-15 10:37:57.112474: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-02-15 10:37:57.112908: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-02-15 10:37:57.162502: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-15 10:37:57.162750: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2080 SUPER computeCapability: 7.5
# coreClock: 1.815GHz coreCount: 48 deviceMemorySize: 7.77GiB deviceMemoryBandwidth: 462.00GiB/s
# 2022-02-15 10:37:57.162764: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-02-15 10:37:57.163697: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-02-15 10:37:57.163725: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-02-15 10:37:57.164648: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-02-15 10:37:57.164789: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-02-15 10:37:57.165732: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-02-15 10:37:57.166257: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-02-15 10:37:57.168279: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-02-15 10:37:57.168332: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-15 10:37:57.168589: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-15 10:37:57.168805: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0

# %% [markdown]
# ### **1. Loading the dataset**
# This assignment will focus on the CIFAR10 dataset. This is a collection of small images in 10 classes such as cars, cats, birds, etc. You can find more information here: https://www.cs.toronto.edu/~kriz/cifar.html. We start by loading and examining the data.

# %%
import numpy as np
from tensorflow.keras.datasets import cifar10

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

print("Shape of training data:")
print(X_train.shape)
print(y_train.shape)
print("Shape of test data:")
print(X_test.shape)
print(y_test.shape)
# Out:
# Shape of training data:
# (50000, 32, 32, 3)
# (50000, 1)
# Shape of test data:
# (10000, 32, 32, 3)
# (10000, 1)

# %% [markdown]
# #### **<span style="color:red">Question 1:</span>**
# The shape of X_train and X_test has 4 values. What do each of these represent?

# %% [markdown]
# ##### **Plotting some images**
# This plots a random selection of images from each class. Rerun the cell to see a different selection.

# %%
from Custom import PlotRandomFromEachClass

cifar_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
PlotRandomFromEachClass(X_train, y_train, 3, labels=cifar_labels)

# %% [markdown]
# ##### **Preparing the dataset**
# Just like the MNIST dataset we normalize the images to [0,1] and transform the class indices to one-hot encoded vectors.

# %%
from tensorflow.keras.utils import to_categorical

# Transform label indices to one-hot encoded vectors
y_train_c = to_categorical(y_train, num_classes=10)
y_test_c  = to_categorical(y_test , num_classes=10)

# Normalization of pixel values (to [0-1] range)
X_train = X_train.astype('float32') / 255
X_test  = X_test.astype('float32')  / 255

# %% [markdown]
# ### **2. Fully connected classifier**
# We will start by creating a fully connected classifier using the ```Dense``` layer. We give you the first layer that flattens the image features to a single vector. Add the remaining layers to the network.
#
# Consider what the size of the output must be and what activation function you should use in the output layer.

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten

x_in = Input(shape=X_train.shape[1:])
x = Flatten()(x_in)

# === Add your code here ===
x = Dense(64, activation='swish')(x)
x = Dense(64, activation='swish')(x)
x = Dense(64, activation='swish')(x)
x = Dense(64, activation='swish')(x)
x = Dense(64, activation='swish')(x)
x = Dense(10, activation='softmax')(x)
# ==========================

model = Model(inputs=x_in, outputs=x)

# Now we build the model using Stochastic Gradient Descent with Nesterov momentum. We use accuracy as the metric.
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])
model.summary(100)
# Out:
# Model: "model"
# ____________________________________________________________________________________________________
# Layer (type)                                 Output Shape                            Param #
# ====================================================================================================
# input_1 (InputLayer)                         [(None, 32, 32, 3)]                     0
# ____________________________________________________________________________________________________
# flatten (Flatten)                            (None, 3072)                            0
# ____________________________________________________________________________________________________
# dense (Dense)                                (None, 64)                              196672
# ____________________________________________________________________________________________________
# dense_1 (Dense)                              (None, 64)                              4160
# ____________________________________________________________________________________________________
# dense_2 (Dense)                              (None, 64)                              4160
# ____________________________________________________________________________________________________
# dense_3 (Dense)                              (None, 64)                              4160
# ____________________________________________________________________________________________________
# dense_4 (Dense)                              (None, 64)                              4160
# ____________________________________________________________________________________________________
# dense_5 (Dense)                              (None, 10)                              650
# ====================================================================================================
# Total params: 213,962
# Trainable params: 213,962
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# 2022-02-15 10:38:10.077971: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-15 10:38:10.078988: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-15 10:38:10.079241: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2080 SUPER computeCapability: 7.5
# coreClock: 1.815GHz coreCount: 48 deviceMemorySize: 7.77GiB deviceMemoryBandwidth: 462.00GiB/s
# 2022-02-15 10:38:10.079260: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-02-15 10:38:10.079275: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-02-15 10:38:10.079284: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-02-15 10:38:10.079292: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-02-15 10:38:10.079301: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-02-15 10:38:10.079309: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-02-15 10:38:10.079318: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-02-15 10:38:10.079327: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-02-15 10:38:10.079365: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-15 10:38:10.079609: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-15 10:38:10.079822: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-02-15 10:38:10.079843: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-02-15 10:38:10.371270: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-02-15 10:38:10.371285: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-02-15 10:38:10.371290: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-02-15 10:38:10.371396: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-15 10:38:10.371627: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-15 10:38:10.371831: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-15 10:38:10.372022: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6877 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 SUPER, pci bus id: 0000:01:00.0, compute capability: 7.5)
# 2022-02-15 10:38:10.372217: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set

# %% [markdown]
# ##### **Training the model**
# In order to show the differences between models in the first parts of the assignment, we will restrict the training to the following command using 15 epochs, batch size 32, and 20% validation data. From section 5 and forward you can change this as you please to increase the accuracy, but for now stick with this command.

# %%
history = model.fit(X_train,y_train_c, epochs=50, batch_size=128, verbose=1, validation_split=0.2)

# %% [markdown]
# ##### **Evaluating the model**
# We use ```model.evaluate``` to get the loss and metric scores on the test data. To plot the results we give you a custom function that does the work for you.

# %%
score = model.evaluate(X_test, y_test_c, batch_size=128, verbose=0)

for i in range(len(score)):
    print("Test " + model.metrics_names[i] + " = %.3f" % score[i])
# Out:
# 2022-02-15 10:38:13.794250: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-02-15 10:38:13.814271: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3699850000 Hz
# Test loss = 2.303
# Test accuracy = 0.096
# 2022-02-15 10:38:14.011872: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10

# %%
from Custom import PlotModelEval

# Custom function for evaluating the model and plotting training history
PlotModelEval(model, history, X_test, y_test, cifar_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_81642/4256192670.py in <module>
#       2
#       3 # Custom function for evaluating the model and plotting training history
# ----> 4 PlotModelEval(model, history, X_test, y_test, cifar_labels)
#
# NameError: name 'history' is not defined

# %% [markdown]
# #### **<span style="color:red">Question 2:</span>**
# Train a model that achieves above 45% accuracy on the test data. In the report, provide a (short) description of your model and show the evaluation image.

# %% [markdown]
# #### **<span style="color:red">Question 3:</span>**
# Compare this model to the one you used for the MNIST dataset in the first assignment, in terms of size and test accuracy. Why do you think this dataset is much harder to classify than the MNIST handwritten digits?

# %% [markdown]
# ### **3. CNN classifier**
# We will now move on to a network architecture that is more suited for this problem, the convolutional neural network. The new layers you will use are ```Conv2D``` and ```MaxPooling2D```, which you can find the documentation of here https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D and here https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D.

# %% [markdown]
# ##### **Creating the CNN model**
#
# A common way to build convolutional neural networks is to create blocks of layers of the form **[convolution - activation - pooling]**, and then stack several of these block to create the full convolution stack. This is often followed by a fully connected network to create the output classes. Use this recipe to build a CNN that acheives at least 62% accuracy on the test data.
#
# *Side note. Although this is a common way to build CNNs, it is be no means the only or even best way. It is a good starting point, but later in part 5 you might want to explore other architectures to acheive even better performance.*

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D

x_in = Input(shape=X_train.shape[1:])

# === Add your code here ===
x = Conv2D(32, kernel_size=(3, 3))(x_in)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(64, kernel_size=(3, 3))(x)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(64, kernel_size=(3, 3))(x)
x = MaxPooling2D((2, 2))(x)
x = Flatten()(x)
x = Dense(64, activation="tanh")(x)
x = Dense(10, activation = "softmax")(x)
# ==========================

model = Model(inputs=x_in, outputs=x)

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=sgd)
model.summary(100)
# Out:
# Model: "model_1"
# ____________________________________________________________________________________________________
# Layer (type)                                 Output Shape                            Param #
# ====================================================================================================
# input_2 (InputLayer)                         [(None, 32, 32, 3)]                     0
# ____________________________________________________________________________________________________
# conv2d (Conv2D)                              (None, 30, 30, 32)                      896
# ____________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)                 (None, 15, 15, 32)                      0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                            (None, 13, 13, 64)                      18496
# ____________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)               (None, 6, 6, 64)                        0
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                            (None, 4, 4, 64)                        36928
# ____________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)               (None, 2, 2, 64)                        0
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)                          (None, 256)                             0
# ____________________________________________________________________________________________________
# dense_6 (Dense)                              (None, 64)                              16448
# ____________________________________________________________________________________________________
# dense_7 (Dense)                              (None, 10)                              650
# ====================================================================================================
# Total params: 73,418
# Trainable params: 73,418
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %% [markdown]
# ##### **Training the CNN**

# %%
history = model.fit(X_train, y_train_c, batch_size=64, epochs=25, verbose=1, validation_split=0.2)

# %% [markdown]
# ##### **Evaluating the CNN**

# %%
score = model.evaluate(X_test, y_test_c, batch_size=128, verbose=0)

for i in range(len(score)):
    print("Test " + model.metrics_names[i] + " = %.3f" % score[i])

# %%
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# #### **<span style="color:red">Question 4:</span>**
# Train a model that achieves at least 62% test accuracy. In the report, provide a (short) description of your model and show the evaluation image.

# %% [markdown]
# #### **<span style="color:red">Question 5:</span>**
# Compare this model with the previous fully connected model. You should find that this one is much more efficient, i.e. achieves higher accuracy with fewer parameters. Explain in your own words how this is possible.

# %% [markdown]
# ### **4. Regularization**

# %% [markdown]
# #### **4.1 Dropout**
# You have probably seen that your CNN model overfits the training data. One way to prevent this is to add ```Dropout``` layers to the model, that randomly "drops" hidden nodes each training-iteration by setting their output to zero. Thus the model cannot rely on a small set of very good hidden features, but must instead learns to use different sets of hidden features each time. Dropout layers are usually added after the pooling layers in the convolution part of the model, or after activations in the fully connected part of the model.
#
# *Side note. In the next assignment you will work with Ensemble models, a way to use the output from several individual models to achieve higher performance than each model can achieve on its own. One way to interpret Dropout is that each random selection of nodes is a separate model that is trained only on the current iteration. The final output is then the average of outputs from all the individual models. In other words, Dropout can be seen as a way to build ensembling directly into the network, without having to train several models explicitly.*
#
# Extend your previous model with the Dropout layer and test the new performance.

# %%
from tensorflow.keras.layers import Dropout

x_in = Input(shape=X_train.shape[1:])

# === Add your code here ===
x = Conv2D(32, kernel_size=(3, 3))(x_in)
x = MaxPooling2D((2, 2))(x)
x = Dropout(0.25)(x)
x = Conv2D(64, kernel_size=(3, 3))(x)
x = MaxPooling2D((2, 2))(x)
x = Dropout(0.25)(x)
x = Conv2D(64, kernel_size=(3, 3))(x)
x = MaxPooling2D((2, 2))(x)
x = Dropout(0.25)(x)
x = Flatten()(x)
x = Dense(64, activation="tanh")(x)
x = Dense(10, activation = "softmax")(x)
# ==========================

model = Model(inputs=x_in, outputs=x)

# Compile model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=sgd)
model.summary(100)
# Out:
# Model: "model_2"
# ____________________________________________________________________________________________________
# Layer (type)                                 Output Shape                            Param #
# ====================================================================================================
# input_3 (InputLayer)                         [(None, 32, 32, 3)]                     0
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                            (None, 30, 30, 32)                      896
# ____________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)               (None, 15, 15, 32)                      0
# ____________________________________________________________________________________________________
# dropout (Dropout)                            (None, 15, 15, 32)                      0
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                            (None, 13, 13, 64)                      18496
# ____________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)               (None, 6, 6, 64)                        0
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)                          (None, 6, 6, 64)                        0
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                            (None, 4, 4, 64)                        36928
# ____________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)               (None, 2, 2, 64)                        0
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)                          (None, 2, 2, 64)                        0
# ____________________________________________________________________________________________________
# flatten_2 (Flatten)                          (None, 256)                             0
# ____________________________________________________________________________________________________
# dense_8 (Dense)                              (None, 64)                              16448
# ____________________________________________________________________________________________________
# dense_9 (Dense)                              (None, 10)                              650
# ====================================================================================================
# Total params: 73,418
# Trainable params: 73,418
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
history = model.fit(X_train, y_train_c, batch_size=64, epochs=25, verbose=1, validation_split=0.2)

# %%
score = model.evaluate(X_test, y_test_c, batch_size=128, verbose=0)

for i in range(len(score)):
    print("Test " + model.metrics_names[i] + " = %.3f" % score[i])

# %%
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# #### **<span style="color:red">Question 6:</span>**
# Train the modified CNN-model. Save the evaluation image for the report.

# %% [markdown]
# #### **<span style="color:red">Question 7:</span>**
# Compare this model and the previous in terms of the training accuracy, validation accuracy, and test accuracy. Explain the similarities and differences (remember that the only difference between the models should be the addition of Dropout layers).
#
# Hint: what does the dropout layer do at test time?

# %% [markdown]
# #### **4.2 Batch normalization**
# The final layer we will explore is ```BatchNormalization```. As the name suggests, this layer normalizes the data in each batch to have a specific mean and standard deviation, which is learned during training. The reason for this is quite complicated (and still debated among the experts), but suffice to say that it helps the optimization converge faster which means we get higher performance in fewer epochs. The normalization is done separatly for each feature, i.e. the statistics are calculated accross the batch dimension of the input data. The equations for batch-normalizing one feature are the following, where $N$ is the batch size, $x$ the input features, and $y$ the normalized output features:
#
# $$ \mu = \frac{1}{N} \sum_{i=0}^{N}x_i,\;\;\;\; \sigma^2 = \frac{1}{N} \sum_{i=0}^{N}(x_i - \mu)^2 $$
#
# $$ \hat{x}_i = \frac{x_i - \mu}{\sqrt{\sigma^2 + \epsilon}} $$
#
# $$ y_i = \gamma \hat{x}_i + \beta $$
#
# At first glance this might look intimidating, but all it means is that we begin by scaling and shifting the data to have mean $\mu=0$ and standard deviation $\sigma=1$. After this we use the learnable parameters $\gamma$ and $\beta$ to decide the width and center of the final distribution. $\epsilon$ is a small constant value that prevents the denominator from being zero.
#
# In addition to learning the parameters $\gamma$ and $\beta$ by gradient decent just like the weights, Batch Normalization also keeps track of the running average of minibatch statistics $\mu$ and $\sigma$. These averages are used to normalize the test data. We can tune the rate at which the running averages are updated with the *momentum* parameter of the BatchNormalization layer. A large momentum means that the statistics converge more slowly and therefore requires more updates before it represents the data. A low momentum, on the other hand, adapts to the data more quickly but might lead to unstable behaviour if the latest minibatches are not representative of the whole dataset. For this test we recommend a momentum of 0.75, but you probably want to change this when you design a larger network in Section 5.
#
# The batch normalization layer should be added after the hidden layer linear transformation, but before the nonlinear activation. This means that we cannot specify the activation funciton in the ```Conv2D``` or ```Dense``` if we want to batch-normalize the output. We therefore need to use the ```Activation``` layer to add a separate activation to the network stack after batch normalization. For example, the convolution block will now look like **[conv - batchnorm - activation - pooling]**.
#
# Extend your previous model with batch normalization, both in the convolution and fully connected part of the model.

# %%
from tensorflow.keras.layers import BatchNormalization, Activation

x_in = Input(shape=X_train.shape[1:])

# === Add your code here ===
x = Conv2D(32, kernel_size=(3, 3))(x_in)
x = BatchNormalization(momentum=0.75)(x)
x = Activation("tanh")(x)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(64, kernel_size=(3, 3))(x)
x = BatchNormalization(momentum=0.75)(x)
x = Activation("tanh")(x)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(64, kernel_size=(3, 3))(x)
x = BatchNormalization(momentum=0.75)(x)
x = Activation("tanh")(x)
x = MaxPooling2D((2, 2))(x)
x = Flatten()(x)
x = Dense(64, activation="tanh")(x)
x = Dense(10, activation = "softmax")(x)
# ==========================

model = Model(inputs=x_in, outputs=x)

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=sgd)
model.summary(100)
# Out:
# Model: "model_3"
# ____________________________________________________________________________________________________
# Layer (type)                                 Output Shape                            Param #
# ====================================================================================================
# input_4 (InputLayer)                         [(None, 32, 32, 3)]                     0
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                            (None, 30, 30, 32)                      896
# ____________________________________________________________________________________________________
# batch_normalization (BatchNormalization)     (None, 30, 30, 32)                      128
# ____________________________________________________________________________________________________
# activation (Activation)                      (None, 30, 30, 32)                      0
# ____________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)               (None, 15, 15, 32)                      0
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                            (None, 13, 13, 64)                      18496
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNormalization)   (None, 13, 13, 64)                      256
# ____________________________________________________________________________________________________
# activation_1 (Activation)                    (None, 13, 13, 64)                      0
# ____________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)               (None, 6, 6, 64)                        0
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                            (None, 4, 4, 64)                        36928
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNormalization)   (None, 4, 4, 64)                        256
# ____________________________________________________________________________________________________
# activation_2 (Activation)                    (None, 4, 4, 64)                        0
# ____________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)               (None, 2, 2, 64)                        0
# ____________________________________________________________________________________________________
# flatten_3 (Flatten)                          (None, 256)                             0
# ____________________________________________________________________________________________________
# dense_10 (Dense)                             (None, 64)                              16448
# ____________________________________________________________________________________________________
# dense_11 (Dense)                             (None, 10)                              650
# ====================================================================================================
# Total params: 74,058
# Trainable params: 73,738
# Non-trainable params: 320
# ____________________________________________________________________________________________________

# %%
history = model.fit(X_train, y_train_c, batch_size=64, epochs=15, verbose=1, validation_split=0.2)

# %%
score = model.evaluate(X_test, y_test_c, batch_size=128, verbose=0)

for i in range(len(score)):
    print("Test " + model.metrics_names[i] + " = %.3f" % score[i])

# %%
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# #### **<span style="color:red">Question 8:</span>**
# Train the model and save the evaluation image for the report.

# %% [markdown]
# #### **<span style="color:red">Question 9:</span>**
# When using BatchNorm one must take care to select a good minibatch size. Describe what problems might arise if the wrong minibatch size is used.
#
# You can reason about this given the description of BatchNorm above, or you can search for the information in other sources. Do not forget to provide links to the sources if you do!

# %% [markdown]
# ### **5. Putting it all together**
# We now want you to create your own model based on what you have learned. We want you to experiment and see what works and what doesn't, so don't go crazy with the number of epochs until you think you have something that works.
#
# To pass this assignment, we want you to acheive **75%** accuracy on the test data in no more than **25 epochs**. This is possible using the layers and techniques we have explored in this notebook, but you are free to use any other methods that we didn't cover. (You are obviously not allowed to cheat, for example by training on the test data.)

# %%
from tensorflow.keras.utils import plot_model

x_in = Input(shape=X_train.shape[1:])

# === Add your code here ===
x = Conv2D(32, kernel_size=(3, 3))(x_in)
x = BatchNormalization(momentum=0.99)(x)
x = Conv2D(32, kernel_size=(3, 3))(x)
x = BatchNormalization(momentum=0.99)(x)
x = MaxPooling2D((2, 2))(x)
x = Dropout(0.25)(x)
x = Conv2D(64, kernel_size=(3, 3))(x)
x = BatchNormalization(momentum=0.99)(x)
x = Conv2D(64, kernel_size=(3, 3))(x)
x = BatchNormalization(momentum=0.99)(x)
x = Conv2D(128, kernel_size=(3, 3))(x)
x = BatchNormalization(momentum=0.99)(x)
x = MaxPooling2D((2, 2))(x)
x = Dropout(0.45)(x)
x = Flatten()(x)
x = Dense(512, activation="swish")(x)
x = BatchNormalization(momentum=0.99)(x)
x = Dense(256, activation="swish")(x)
x = BatchNormalization(momentum=0.99)(x)
x = Dense(10, activation = "softmax")(x)
# ==========================

model = Model(inputs=x_in, outputs=x)

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=sgd)
model.summary(100)
plot_model(model, show_shapes=True, show_layer_names=False)
# Out:
# Model: "model_4"
# ____________________________________________________________________________________________________
# Layer (type)                                 Output Shape                            Param #
# ====================================================================================================
# input_5 (InputLayer)                         [(None, 32, 32, 3)]                     0
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                            (None, 30, 30, 32)                      896
# ____________________________________________________________________________________________________
# batch_normalization_3 (BatchNormalization)   (None, 30, 30, 32)                      128
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)                           (None, 28, 28, 32)                      9248
# ____________________________________________________________________________________________________
# batch_normalization_4 (BatchNormalization)   (None, 28, 28, 32)                      128
# ____________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)               (None, 14, 14, 32)                      0
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)                          (None, 14, 14, 32)                      0
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)                           (None, 12, 12, 64)                      18496
# ____________________________________________________________________________________________________
# batch_normalization_5 (BatchNormalization)   (None, 12, 12, 64)                      256
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)                           (None, 10, 10, 64)                      36928
# ____________________________________________________________________________________________________
# batch_normalization_6 (BatchNormalization)   (None, 10, 10, 64)                      256
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)                           (None, 8, 8, 128)                       73856
# ____________________________________________________________________________________________________
# batch_normalization_7 (BatchNormalization)   (None, 8, 8, 128)                       512
# ____________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D)              (None, 4, 4, 128)                       0
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)                          (None, 4, 4, 128)                       0
# ____________________________________________________________________________________________________
# flatten_4 (Flatten)                          (None, 2048)                            0
# ____________________________________________________________________________________________________
# dense_12 (Dense)                             (None, 512)                             1049088
# ____________________________________________________________________________________________________
# batch_normalization_8 (BatchNormalization)   (None, 512)                             2048
# ____________________________________________________________________________________________________
# dense_13 (Dense)                             (None, 256)                             131328
# ____________________________________________________________________________________________________
# batch_normalization_9 (BatchNormalization)   (None, 256)                             1024
# ____________________________________________________________________________________________________
# dense_14 (Dense)                             (None, 10)                              2570
# ====================================================================================================
# Total params: 1,326,762
# Trainable params: 1,324,586
# Non-trainable params: 2,176
# ____________________________________________________________________________________________________

# %%
history = model.fit(X_train, y_train_c, batch_size=256, epochs=25, verbose=1, validation_split=0.2)

# %%
score = model.evaluate(X_test, y_test_c, batch_size=128, verbose=0)

for i in range(len(score)):
    print("Test " + model.metrics_names[i] + " = %.3f" % score[i])

# %%
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# #### **<span style="color:red">Question 10:</span>**
# Design and train a model that achieves at least 75% test accuracy in at most 25 epochs. Save the evaluation image for the report. Also, in the report you should explain your model and motivate the design choices you have made.

# %% [markdown]
# ### **Want some extra challenge?**
# For those of you that feel the competitive spark right now, we will hold an **optional** competition where you can submit your trained model-file for evaluation. To make this fair, you are not allowed to train for more than **50 epochs**, but other than that we want you to get creative. The competition is simple, we will evaluate all submitted models and the model with highest test accuracy wins. The prize is nothing less than eternal glory.
#
# Here are some things to look into, but note that we don't have the answers here. Any of these might improve the performance, or might not, or it might only work in combination with each other. This is up to you to figure out. This is how deep learning research often happens, trying things in a smart way to see what works best.
# * Tweak or change the optimizer or training parameters.
# * Tweak the filter parameters, such as numbers and sizes of filters.
# * Use other activation functions.
# * Add L1/L2 regularization (see https://www.tensorflow.org/api_docs/python/tf/keras/regularizers)
# * Include layers that we did not cover here (see https://www.tensorflow.org/api_docs/python/tf/keras/layers). For example, our best model uses the global pooling layers.
# * Take inspiration from some well-known architectures, such as ResNet or VGG16. (But don't just copy-paste those architectures. For one, what's the fun in that? Also, they take a long time to train, you will not have time.)
# * Use explicit model ensembing (training multiple models that vote on or average the outputs - this will also take a lot of time.)
# * Use data augmentation to create a larger training set (see https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator).
#
# Write your competition model here. This way you can try different things without deleting the model you created above. Also set the GroupName variable to your LiU IDs or some unique name; that way our scripts can be a lot easier, thanks and good luck :)

# %%
from tensorflow.keras.layers import Add, AveragePooling2D, ZeroPadding2D, MaxPool2D, concatenate, LocallyConnected2D, LeakyReLU
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.initializers import GlorotNormal

# Split data for validation data
#X_len = len(X_train)
#X_validate = X_train[0:5000]
#y_validate_c = y_train[0:5000]
#X_train = X_train[5000:X_len]
#y_train_c = y_train[5000:X_len]


# Set initializer to Xavier normal
xav_initializer = GlorotNormal()

## Data augmentation
aug = ImageDataGenerator(width_shift_range = 0.1, height_shift_range = 0.1, horizontal_flip = True, fill_mode = "nearest")

aug_train = aug.flow(X_train, y_train_c, batch_size = 64)

def convolutional_block(x, n_filters ,filter_sizeX, filter_sizeY, stride, axises, padding = "same"):
    """Basic convolutional block; with 2D convolution, then batch normalization and finally activating with relu"""
    x = Conv2D(n_filters,(filter_sizeX, filter_sizeY), strides=stride, padding=padding, kernel_initializer = xav_initializer)(x)
    x = BatchNormalization(axis = axises)(x)
    x = LeakyReLU(0.2)(x)
    return x

def inception_block(x, conv1_size, conv2_size, conv5_size, n_pooling, axises):
    """Three separate convolutional blocks (1x1, 3x3 and 5x5) and a block of maxpooling followed by a convolution. 
    Then put together all of them and return """
    conv_1 = convolutional_block(x, conv1_size, 1, 1,(1, 1), axises) 
    conv_3 = convolutional_block(x, conv2_size, 3, 3,(1, 1), axises)
    conv_5 = convolutional_block(x, conv5_size, 5, 5,(1, 1), axises)
        
    pooled = MaxPooling2D((3, 3), strides=(1, 1), padding = "same")(x)
    pooled = Conv2D(n_pooling, (1, 1), padding = "same", activation = "relu", kernel_initializer = xav_initializer)(pooled)
    
    x = concatenate([conv_1, conv_3, conv_5, pooled], axis=axises)
    return x


def downsample_block(x, n_filters, axises):
    """For a given input runs one convolutional block, and a pooling of input then puts together"""
    conv_3 = convolutional_block(x, n_filters,3,3,(2,2), axises, padding = "valid")
    pool = MaxPooling2D((3,3),strides=(2,2))(x)
    x = concatenate([conv_3,pool],axis = axises)
    return x

n_epochs = 50
init_lr = 5e-3

def polynomial_decay(epoch):
    """Function to allow for polynomial decay of the learning rate"""
    maxEpochs = n_epochs
    baseLR = init_lr
    alpha = baseLR * (1 - (epoch / float(maxEpochs)))
    return alpha

#print(len(X_validate))
#print(len(X_train))

# %%
GroupName = "Test"

x_in = Input(shape=X_train.shape[1:])
x = convolutional_block(x_in, n_filters = 96, filter_sizeX = 3, filter_sizeY = 3, stride = (1, 1), axises = -1)
x = inception_block(x, conv1_size = 32, conv2_size = 32, conv5_size = 32, n_pooling = 32, axises = -1)
x_temp = inception_lock(x, conv1_size = 32, conv2_size = 48, conv5_size = 48, n_pooling = 32, axises = -1)

x = downsample_block(x_temp, n_filters = 80, axises = -1)
x1 = downsample_block(x_temp, n_filters = 80, axises = -1)

x = inception_block(x, conv1_size = 112, conv2_size = 48, conv5_size = 32, n_pooling = 48, axises = -1)
x = inception_block(x, conv1_size = 96, conv2_size = 64, conv5_size = 32, n_pooling = 32, axises = -1) # Output (15,15, 224)

x1 = inception_block(x1, conv1_size = 112, conv2_size = 48, conv5_size = 32, n_pooling = 48, axises = -1)
x1 = inception_block(x1, conv1_size = 96, conv2_size = 64, conv5_size = 32, n_pooling = 32, axises = -1) # Output (15,15,224)

x_temp = concatenate([x,x1], axis = -1) # Output (15,15, 448)
x_temp = convolutional_block(x_temp, n_filters = 336, filter_sizeX = 3, filter_sizeY=3, stride = (1,1), axises = -1)

x_temp = convolutional_block(x_temp, n_filters = 224, filter_sizeX = 1, filter_sizeY=1, stride = (1,1), axises = -1)

# Residual block




x = inception_block(x_temp, conv1_size = 80, conv2_size = 80, conv5_size = 32, n_pooling = 32, axises = -1)
x1 = inception_block(x_temp, conv1_size = 80, conv2_size = 80, conv5_size = 32, n_pooling = 32, axises = -1)


x = inception_block(x, conv1_size = 48, conv2_size = 96, conv5_size = 32, n_pooling = 32, axises = -1)
x = inception_block(x, conv1_size = 112, conv2_size = 48, conv5_size = 32, n_pooling = 48, axises = -1)


x1 = inception_block(x1, conv1_size = 48, conv2_size = 96, conv5_size = 32, n_pooling = 32, axises = -1)
x1 = inception_block(x1, conv1_size = 112, conv2_size = 48, conv5_size = 32, n_pooling = 48, axises = -1)

x = downsample_block(x, n_filters = 96, axises = -1)
x1 = downsample_block(x1, n_filters = 96, axises = -1)

x_temp = concatenate([x,x1], axis = -1) # Ouput(7,7,372)
x_temp = convolutional_block(x_temp, n_filters = 504, filter_sizeX = 3, filter_sizeY = 3, stride = (1,1), axises = -1)
x_temp = convolutional_block(x_temp, n_filters = 336, filter_sizeX = 1, filter_sizeY = 1, stride = (1,1), axises = -1)


x = inception_block(x_temp, conv1_size = 176, conv2_size = 160, conv5_size = 96, n_pooling = 96, axises = -1)
x = inception_block(x, conv1_size = 176, conv2_size = 160, conv5_size = 96, n_pooling = 96, axises = -1)

x1 = inception_block(x_temp, conv1_size = 176, conv2_size = 160, conv5_size = 96, n_pooling = 96, axises = -1)
x1 = inception_block(x1, conv1_size = 176, conv2_size = 160, conv5_size = 96, n_pooling = 96, axises = -1)

x = concatenate([x,x1], axis = -1)

x = AveragePooling2D((7, 7))(x)
x = Dropout(0.5)(x)
x = Flatten()(x)
x = Dense(10)(x)
x = Activation("softmax")(x)

model = Model(inputs=x_in, outputs=x, name=GroupName)

earlystopp = EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=1, mode='auto')
  
callback = [LearningRateScheduler(polynomial_decay), earlystopp]

opt = SGD(lr=init_lr, momentum=0.9)
   
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=opt)

#https://machinelearningknowledge.ai/googlenet-architecture-implementation-in-keras-with-cifar-10-dataset/#Architecture_of_GoogleNet

# Print the summary and model image

# %%
model.summary(100)
plot_model(model, show_shapes=True, show_layer_names=False)
# Out:
# Model: "Test"
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_15 (InputLayer)            [(None, 32, 32, 3)]   0
# ____________________________________________________________________________________________________
# conv2d_597 (Conv2D)              (None, 32, 32, 96)    2688        input_15[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_465 (BatchNo (None, 32, 32, 96)    384         conv2d_597[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_455 (LeakyReLU)      (None, 32, 32, 96)    0           batch_normalization_465[0][0]
# ____________________________________________________________________________________________________
# conv2d_598 (Conv2D)              (None, 32, 32, 32)    3104        leaky_re_lu_455[0][0]
# ____________________________________________________________________________________________________
# conv2d_599 (Conv2D)              (None, 32, 32, 32)    27680       leaky_re_lu_455[0][0]
# ____________________________________________________________________________________________________
# conv2d_600 (Conv2D)              (None, 32, 32, 32)    76832       leaky_re_lu_455[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_466 (BatchNo (None, 32, 32, 32)    128         conv2d_598[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_467 (BatchNo (None, 32, 32, 32)    128         conv2d_599[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_468 (BatchNo (None, 32, 32, 32)    128         conv2d_600[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_171 (MaxPooling2D) (None, 32, 32, 96)    0           leaky_re_lu_455[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_456 (LeakyReLU)      (None, 32, 32, 32)    0           batch_normalization_466[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_457 (LeakyReLU)      (None, 32, 32, 32)    0           batch_normalization_467[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_458 (LeakyReLU)      (None, 32, 32, 32)    0           batch_normalization_468[0][0]
# ____________________________________________________________________________________________________
# conv2d_601 (Conv2D)              (None, 32, 32, 32)    3104        max_pooling2d_171[0][0]
# ____________________________________________________________________________________________________
# concatenate_184 (Concatenate)    (None, 32, 32, 128)   0           leaky_re_lu_456[0][0]
#                                                                    leaky_re_lu_457[0][0]
#                                                                    leaky_re_lu_458[0][0]
#                                                                    conv2d_601[0][0]
# ____________________________________________________________________________________________________
# conv2d_602 (Conv2D)              (None, 32, 32, 32)    4128        concatenate_184[0][0]
# ____________________________________________________________________________________________________
# conv2d_603 (Conv2D)              (None, 32, 32, 48)    55344       concatenate_184[0][0]
# ____________________________________________________________________________________________________
# conv2d_604 (Conv2D)              (None, 32, 32, 48)    153648      concatenate_184[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_469 (BatchNo (None, 32, 32, 32)    128         conv2d_602[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_470 (BatchNo (None, 32, 32, 48)    192         conv2d_603[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_471 (BatchNo (None, 32, 32, 48)    192         conv2d_604[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_172 (MaxPooling2D) (None, 32, 32, 128)   0           concatenate_184[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_459 (LeakyReLU)      (None, 32, 32, 32)    0           batch_normalization_469[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_460 (LeakyReLU)      (None, 32, 32, 48)    0           batch_normalization_470[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_461 (LeakyReLU)      (None, 32, 32, 48)    0           batch_normalization_471[0][0]
# ____________________________________________________________________________________________________
# conv2d_605 (Conv2D)              (None, 32, 32, 32)    4128        max_pooling2d_172[0][0]
# ____________________________________________________________________________________________________
# concatenate_185 (Concatenate)    (None, 32, 32, 160)   0           leaky_re_lu_459[0][0]
#                                                                    leaky_re_lu_460[0][0]
#                                                                    leaky_re_lu_461[0][0]
#                                                                    conv2d_605[0][0]
# ____________________________________________________________________________________________________
# conv2d_606 (Conv2D)              (None, 15, 15, 80)    115280      concatenate_185[0][0]
# ____________________________________________________________________________________________________
# conv2d_607 (Conv2D)              (None, 15, 15, 80)    115280      concatenate_185[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_472 (BatchNo (None, 15, 15, 80)    320         conv2d_606[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_473 (BatchNo (None, 15, 15, 80)    320         conv2d_607[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_462 (LeakyReLU)      (None, 15, 15, 80)    0           batch_normalization_472[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_173 (MaxPooling2D) (None, 15, 15, 160)   0           concatenate_185[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_463 (LeakyReLU)      (None, 15, 15, 80)    0           batch_normalization_473[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_174 (MaxPooling2D) (None, 15, 15, 160)   0           concatenate_185[0][0]
# ____________________________________________________________________________________________________
# concatenate_186 (Concatenate)    (None, 15, 15, 240)   0           leaky_re_lu_462[0][0]
#                                                                    max_pooling2d_173[0][0]
# ____________________________________________________________________________________________________
# concatenate_187 (Concatenate)    (None, 15, 15, 240)   0           leaky_re_lu_463[0][0]
#                                                                    max_pooling2d_174[0][0]
# ____________________________________________________________________________________________________
# conv2d_608 (Conv2D)              (None, 15, 15, 112)   26992       concatenate_186[0][0]
# ____________________________________________________________________________________________________
# conv2d_609 (Conv2D)              (None, 15, 15, 48)    103728      concatenate_186[0][0]
# ____________________________________________________________________________________________________
# conv2d_610 (Conv2D)              (None, 15, 15, 32)    192032      concatenate_186[0][0]
# ____________________________________________________________________________________________________
# conv2d_616 (Conv2D)              (None, 15, 15, 112)   26992       concatenate_187[0][0]
# ____________________________________________________________________________________________________
# conv2d_617 (Conv2D)              (None, 15, 15, 48)    103728      concatenate_187[0][0]
# ____________________________________________________________________________________________________
# conv2d_618 (Conv2D)              (None, 15, 15, 32)    192032      concatenate_187[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_474 (BatchNo (None, 15, 15, 112)   448         conv2d_608[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_475 (BatchNo (None, 15, 15, 48)    192         conv2d_609[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_476 (BatchNo (None, 15, 15, 32)    128         conv2d_610[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_175 (MaxPooling2D) (None, 15, 15, 240)   0           concatenate_186[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_480 (BatchNo (None, 15, 15, 112)   448         conv2d_616[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_481 (BatchNo (None, 15, 15, 48)    192         conv2d_617[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_482 (BatchNo (None, 15, 15, 32)    128         conv2d_618[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_177 (MaxPooling2D) (None, 15, 15, 240)   0           concatenate_187[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_464 (LeakyReLU)      (None, 15, 15, 112)   0           batch_normalization_474[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_465 (LeakyReLU)      (None, 15, 15, 48)    0           batch_normalization_475[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_466 (LeakyReLU)      (None, 15, 15, 32)    0           batch_normalization_476[0][0]
# ____________________________________________________________________________________________________
# conv2d_611 (Conv2D)              (None, 15, 15, 48)    11568       max_pooling2d_175[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_470 (LeakyReLU)      (None, 15, 15, 112)   0           batch_normalization_480[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_471 (LeakyReLU)      (None, 15, 15, 48)    0           batch_normalization_481[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_472 (LeakyReLU)      (None, 15, 15, 32)    0           batch_normalization_482[0][0]
# ____________________________________________________________________________________________________
# conv2d_619 (Conv2D)              (None, 15, 15, 48)    11568       max_pooling2d_177[0][0]
# ____________________________________________________________________________________________________
# concatenate_188 (Concatenate)    (None, 15, 15, 240)   0           leaky_re_lu_464[0][0]
#                                                                    leaky_re_lu_465[0][0]
#                                                                    leaky_re_lu_466[0][0]
#                                                                    conv2d_611[0][0]
# ____________________________________________________________________________________________________
# concatenate_190 (Concatenate)    (None, 15, 15, 240)   0           leaky_re_lu_470[0][0]
#                                                                    leaky_re_lu_471[0][0]
#                                                                    leaky_re_lu_472[0][0]
#                                                                    conv2d_619[0][0]
# ____________________________________________________________________________________________________
# conv2d_612 (Conv2D)              (None, 15, 15, 96)    23136       concatenate_188[0][0]
# ____________________________________________________________________________________________________
# conv2d_613 (Conv2D)              (None, 15, 15, 64)    138304      concatenate_188[0][0]
# ____________________________________________________________________________________________________
# conv2d_614 (Conv2D)              (None, 15, 15, 32)    192032      concatenate_188[0][0]
# ____________________________________________________________________________________________________
# conv2d_620 (Conv2D)              (None, 15, 15, 96)    23136       concatenate_190[0][0]
# ____________________________________________________________________________________________________
# conv2d_621 (Conv2D)              (None, 15, 15, 64)    138304      concatenate_190[0][0]
# ____________________________________________________________________________________________________
# conv2d_622 (Conv2D)              (None, 15, 15, 32)    192032      concatenate_190[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_477 (BatchNo (None, 15, 15, 96)    384         conv2d_612[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_478 (BatchNo (None, 15, 15, 64)    256         conv2d_613[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_479 (BatchNo (None, 15, 15, 32)    128         conv2d_614[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_176 (MaxPooling2D) (None, 15, 15, 240)   0           concatenate_188[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_483 (BatchNo (None, 15, 15, 96)    384         conv2d_620[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_484 (BatchNo (None, 15, 15, 64)    256         conv2d_621[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_485 (BatchNo (None, 15, 15, 32)    128         conv2d_622[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_178 (MaxPooling2D) (None, 15, 15, 240)   0           concatenate_190[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_467 (LeakyReLU)      (None, 15, 15, 96)    0           batch_normalization_477[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_468 (LeakyReLU)      (None, 15, 15, 64)    0           batch_normalization_478[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_469 (LeakyReLU)      (None, 15, 15, 32)    0           batch_normalization_479[0][0]
# ____________________________________________________________________________________________________
# conv2d_615 (Conv2D)              (None, 15, 15, 32)    7712        max_pooling2d_176[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_473 (LeakyReLU)      (None, 15, 15, 96)    0           batch_normalization_483[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_474 (LeakyReLU)      (None, 15, 15, 64)    0           batch_normalization_484[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_475 (LeakyReLU)      (None, 15, 15, 32)    0           batch_normalization_485[0][0]
# ____________________________________________________________________________________________________
# conv2d_623 (Conv2D)              (None, 15, 15, 32)    7712        max_pooling2d_178[0][0]
# ____________________________________________________________________________________________________
# concatenate_189 (Concatenate)    (None, 15, 15, 224)   0           leaky_re_lu_467[0][0]
#                                                                    leaky_re_lu_468[0][0]
#                                                                    leaky_re_lu_469[0][0]
#                                                                    conv2d_615[0][0]
# ____________________________________________________________________________________________________
# concatenate_191 (Concatenate)    (None, 15, 15, 224)   0           leaky_re_lu_473[0][0]
#                                                                    leaky_re_lu_474[0][0]
#                                                                    leaky_re_lu_475[0][0]
#                                                                    conv2d_623[0][0]
# ____________________________________________________________________________________________________
# concatenate_192 (Concatenate)    (None, 15, 15, 448)   0           concatenate_189[0][0]
#                                                                    concatenate_191[0][0]
# ____________________________________________________________________________________________________
# conv2d_624 (Conv2D)              (None, 15, 15, 336)   1355088     concatenate_192[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_486 (BatchNo (None, 15, 15, 336)   1344        conv2d_624[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_476 (LeakyReLU)      (None, 15, 15, 336)   0           batch_normalization_486[0][0]
# ____________________________________________________________________________________________________
# conv2d_625 (Conv2D)              (None, 15, 15, 224)   75488       leaky_re_lu_476[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_487 (BatchNo (None, 15, 15, 224)   896         conv2d_625[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_477 (LeakyReLU)      (None, 15, 15, 224)   0           batch_normalization_487[0][0]
# ____________________________________________________________________________________________________
# conv2d_626 (Conv2D)              (None, 15, 15, 80)    18000       leaky_re_lu_477[0][0]
# ____________________________________________________________________________________________________
# conv2d_627 (Conv2D)              (None, 15, 15, 80)    161360      leaky_re_lu_477[0][0]
# ____________________________________________________________________________________________________
# conv2d_628 (Conv2D)              (None, 15, 15, 32)    179232      leaky_re_lu_477[0][0]
# ____________________________________________________________________________________________________
# conv2d_630 (Conv2D)              (None, 15, 15, 80)    18000       leaky_re_lu_477[0][0]
# ____________________________________________________________________________________________________
# conv2d_631 (Conv2D)              (None, 15, 15, 80)    161360      leaky_re_lu_477[0][0]
# ____________________________________________________________________________________________________
# conv2d_632 (Conv2D)              (None, 15, 15, 32)    179232      leaky_re_lu_477[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_488 (BatchNo (None, 15, 15, 80)    320         conv2d_626[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_489 (BatchNo (None, 15, 15, 80)    320         conv2d_627[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_490 (BatchNo (None, 15, 15, 32)    128         conv2d_628[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_179 (MaxPooling2D) (None, 15, 15, 224)   0           leaky_re_lu_477[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_491 (BatchNo (None, 15, 15, 80)    320         conv2d_630[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_492 (BatchNo (None, 15, 15, 80)    320         conv2d_631[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_493 (BatchNo (None, 15, 15, 32)    128         conv2d_632[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_180 (MaxPooling2D) (None, 15, 15, 224)   0           leaky_re_lu_477[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_478 (LeakyReLU)      (None, 15, 15, 80)    0           batch_normalization_488[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_479 (LeakyReLU)      (None, 15, 15, 80)    0           batch_normalization_489[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_480 (LeakyReLU)      (None, 15, 15, 32)    0           batch_normalization_490[0][0]
# ____________________________________________________________________________________________________
# conv2d_629 (Conv2D)              (None, 15, 15, 32)    7200        max_pooling2d_179[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_481 (LeakyReLU)      (None, 15, 15, 80)    0           batch_normalization_491[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_482 (LeakyReLU)      (None, 15, 15, 80)    0           batch_normalization_492[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_483 (LeakyReLU)      (None, 15, 15, 32)    0           batch_normalization_493[0][0]
# ____________________________________________________________________________________________________
# conv2d_633 (Conv2D)              (None, 15, 15, 32)    7200        max_pooling2d_180[0][0]
# ____________________________________________________________________________________________________
# concatenate_193 (Concatenate)    (None, 15, 15, 224)   0           leaky_re_lu_478[0][0]
#                                                                    leaky_re_lu_479[0][0]
#                                                                    leaky_re_lu_480[0][0]
#                                                                    conv2d_629[0][0]
# ____________________________________________________________________________________________________
# concatenate_194 (Concatenate)    (None, 15, 15, 224)   0           leaky_re_lu_481[0][0]
#                                                                    leaky_re_lu_482[0][0]
#                                                                    leaky_re_lu_483[0][0]
#                                                                    conv2d_633[0][0]
# ____________________________________________________________________________________________________
# conv2d_634 (Conv2D)              (None, 15, 15, 48)    10800       concatenate_193[0][0]
# ____________________________________________________________________________________________________
# conv2d_635 (Conv2D)              (None, 15, 15, 96)    193632      concatenate_193[0][0]
# ____________________________________________________________________________________________________
# conv2d_636 (Conv2D)              (None, 15, 15, 32)    179232      concatenate_193[0][0]
# ____________________________________________________________________________________________________
# conv2d_642 (Conv2D)              (None, 15, 15, 48)    10800       concatenate_194[0][0]
# ____________________________________________________________________________________________________
# conv2d_643 (Conv2D)              (None, 15, 15, 96)    193632      concatenate_194[0][0]
# ____________________________________________________________________________________________________
# conv2d_644 (Conv2D)              (None, 15, 15, 32)    179232      concatenate_194[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_494 (BatchNo (None, 15, 15, 48)    192         conv2d_634[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_495 (BatchNo (None, 15, 15, 96)    384         conv2d_635[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_496 (BatchNo (None, 15, 15, 32)    128         conv2d_636[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_181 (MaxPooling2D) (None, 15, 15, 224)   0           concatenate_193[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_500 (BatchNo (None, 15, 15, 48)    192         conv2d_642[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_501 (BatchNo (None, 15, 15, 96)    384         conv2d_643[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_502 (BatchNo (None, 15, 15, 32)    128         conv2d_644[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_183 (MaxPooling2D) (None, 15, 15, 224)   0           concatenate_194[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_484 (LeakyReLU)      (None, 15, 15, 48)    0           batch_normalization_494[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_485 (LeakyReLU)      (None, 15, 15, 96)    0           batch_normalization_495[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_486 (LeakyReLU)      (None, 15, 15, 32)    0           batch_normalization_496[0][0]
# ____________________________________________________________________________________________________
# conv2d_637 (Conv2D)              (None, 15, 15, 32)    7200        max_pooling2d_181[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_490 (LeakyReLU)      (None, 15, 15, 48)    0           batch_normalization_500[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_491 (LeakyReLU)      (None, 15, 15, 96)    0           batch_normalization_501[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_492 (LeakyReLU)      (None, 15, 15, 32)    0           batch_normalization_502[0][0]
# ____________________________________________________________________________________________________
# conv2d_645 (Conv2D)              (None, 15, 15, 32)    7200        max_pooling2d_183[0][0]
# ____________________________________________________________________________________________________
# concatenate_195 (Concatenate)    (None, 15, 15, 208)   0           leaky_re_lu_484[0][0]
#                                                                    leaky_re_lu_485[0][0]
#                                                                    leaky_re_lu_486[0][0]
#                                                                    conv2d_637[0][0]
# ____________________________________________________________________________________________________
# concatenate_197 (Concatenate)    (None, 15, 15, 208)   0           leaky_re_lu_490[0][0]
#                                                                    leaky_re_lu_491[0][0]
#                                                                    leaky_re_lu_492[0][0]
#                                                                    conv2d_645[0][0]
# ____________________________________________________________________________________________________
# conv2d_638 (Conv2D)              (None, 15, 15, 112)   23408       concatenate_195[0][0]
# ____________________________________________________________________________________________________
# conv2d_639 (Conv2D)              (None, 15, 15, 48)    89904       concatenate_195[0][0]
# ____________________________________________________________________________________________________
# conv2d_640 (Conv2D)              (None, 15, 15, 32)    166432      concatenate_195[0][0]
# ____________________________________________________________________________________________________
# conv2d_646 (Conv2D)              (None, 15, 15, 112)   23408       concatenate_197[0][0]
# ____________________________________________________________________________________________________
# conv2d_647 (Conv2D)              (None, 15, 15, 48)    89904       concatenate_197[0][0]
# ____________________________________________________________________________________________________
# conv2d_648 (Conv2D)              (None, 15, 15, 32)    166432      concatenate_197[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_497 (BatchNo (None, 15, 15, 112)   448         conv2d_638[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_498 (BatchNo (None, 15, 15, 48)    192         conv2d_639[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_499 (BatchNo (None, 15, 15, 32)    128         conv2d_640[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_182 (MaxPooling2D) (None, 15, 15, 208)   0           concatenate_195[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_503 (BatchNo (None, 15, 15, 112)   448         conv2d_646[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_504 (BatchNo (None, 15, 15, 48)    192         conv2d_647[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_505 (BatchNo (None, 15, 15, 32)    128         conv2d_648[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_184 (MaxPooling2D) (None, 15, 15, 208)   0           concatenate_197[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_487 (LeakyReLU)      (None, 15, 15, 112)   0           batch_normalization_497[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_488 (LeakyReLU)      (None, 15, 15, 48)    0           batch_normalization_498[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_489 (LeakyReLU)      (None, 15, 15, 32)    0           batch_normalization_499[0][0]
# ____________________________________________________________________________________________________
# conv2d_641 (Conv2D)              (None, 15, 15, 48)    10032       max_pooling2d_182[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_493 (LeakyReLU)      (None, 15, 15, 112)   0           batch_normalization_503[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_494 (LeakyReLU)      (None, 15, 15, 48)    0           batch_normalization_504[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_495 (LeakyReLU)      (None, 15, 15, 32)    0           batch_normalization_505[0][0]
# ____________________________________________________________________________________________________
# conv2d_649 (Conv2D)              (None, 15, 15, 48)    10032       max_pooling2d_184[0][0]
# ____________________________________________________________________________________________________
# concatenate_196 (Concatenate)    (None, 15, 15, 240)   0           leaky_re_lu_487[0][0]
#                                                                    leaky_re_lu_488[0][0]
#                                                                    leaky_re_lu_489[0][0]
#                                                                    conv2d_641[0][0]
# ____________________________________________________________________________________________________
# concatenate_198 (Concatenate)    (None, 15, 15, 240)   0           leaky_re_lu_493[0][0]
#                                                                    leaky_re_lu_494[0][0]
#                                                                    leaky_re_lu_495[0][0]
#                                                                    conv2d_649[0][0]
# ____________________________________________________________________________________________________
# conv2d_650 (Conv2D)              (None, 7, 7, 96)      207456      concatenate_196[0][0]
# ____________________________________________________________________________________________________
# conv2d_651 (Conv2D)              (None, 7, 7, 96)      207456      concatenate_198[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_506 (BatchNo (None, 7, 7, 96)      384         conv2d_650[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_507 (BatchNo (None, 7, 7, 96)      384         conv2d_651[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_496 (LeakyReLU)      (None, 7, 7, 96)      0           batch_normalization_506[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_185 (MaxPooling2D) (None, 7, 7, 240)     0           concatenate_196[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_497 (LeakyReLU)      (None, 7, 7, 96)      0           batch_normalization_507[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_186 (MaxPooling2D) (None, 7, 7, 240)     0           concatenate_198[0][0]
# ____________________________________________________________________________________________________
# concatenate_199 (Concatenate)    (None, 7, 7, 336)     0           leaky_re_lu_496[0][0]
#                                                                    max_pooling2d_185[0][0]
# ____________________________________________________________________________________________________
# concatenate_200 (Concatenate)    (None, 7, 7, 336)     0           leaky_re_lu_497[0][0]
#                                                                    max_pooling2d_186[0][0]
# ____________________________________________________________________________________________________
# concatenate_201 (Concatenate)    (None, 7, 7, 672)     0           concatenate_199[0][0]
#                                                                    concatenate_200[0][0]
# ____________________________________________________________________________________________________
# conv2d_652 (Conv2D)              (None, 7, 7, 504)     3048696     concatenate_201[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_508 (BatchNo (None, 7, 7, 504)     2016        conv2d_652[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_498 (LeakyReLU)      (None, 7, 7, 504)     0           batch_normalization_508[0][0]
# ____________________________________________________________________________________________________
# conv2d_653 (Conv2D)              (None, 7, 7, 336)     169680      leaky_re_lu_498[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_509 (BatchNo (None, 7, 7, 336)     1344        conv2d_653[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_499 (LeakyReLU)      (None, 7, 7, 336)     0           batch_normalization_509[0][0]
# ____________________________________________________________________________________________________
# conv2d_654 (Conv2D)              (None, 7, 7, 176)     59312       leaky_re_lu_499[0][0]
# ____________________________________________________________________________________________________
# conv2d_655 (Conv2D)              (None, 7, 7, 160)     484000      leaky_re_lu_499[0][0]
# ____________________________________________________________________________________________________
# conv2d_656 (Conv2D)              (None, 7, 7, 96)      806496      leaky_re_lu_499[0][0]
# ____________________________________________________________________________________________________
# conv2d_662 (Conv2D)              (None, 7, 7, 176)     59312       leaky_re_lu_499[0][0]
# ____________________________________________________________________________________________________
# conv2d_663 (Conv2D)              (None, 7, 7, 160)     484000      leaky_re_lu_499[0][0]
# ____________________________________________________________________________________________________
# conv2d_664 (Conv2D)              (None, 7, 7, 96)      806496      leaky_re_lu_499[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_510 (BatchNo (None, 7, 7, 176)     704         conv2d_654[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_511 (BatchNo (None, 7, 7, 160)     640         conv2d_655[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_512 (BatchNo (None, 7, 7, 96)      384         conv2d_656[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_187 (MaxPooling2D) (None, 7, 7, 336)     0           leaky_re_lu_499[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_516 (BatchNo (None, 7, 7, 176)     704         conv2d_662[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_517 (BatchNo (None, 7, 7, 160)     640         conv2d_663[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_518 (BatchNo (None, 7, 7, 96)      384         conv2d_664[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_189 (MaxPooling2D) (None, 7, 7, 336)     0           leaky_re_lu_499[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_500 (LeakyReLU)      (None, 7, 7, 176)     0           batch_normalization_510[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_501 (LeakyReLU)      (None, 7, 7, 160)     0           batch_normalization_511[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_502 (LeakyReLU)      (None, 7, 7, 96)      0           batch_normalization_512[0][0]
# ____________________________________________________________________________________________________
# conv2d_657 (Conv2D)              (None, 7, 7, 96)      32352       max_pooling2d_187[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_506 (LeakyReLU)      (None, 7, 7, 176)     0           batch_normalization_516[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_507 (LeakyReLU)      (None, 7, 7, 160)     0           batch_normalization_517[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_508 (LeakyReLU)      (None, 7, 7, 96)      0           batch_normalization_518[0][0]
# ____________________________________________________________________________________________________
# conv2d_665 (Conv2D)              (None, 7, 7, 96)      32352       max_pooling2d_189[0][0]
# ____________________________________________________________________________________________________
# concatenate_202 (Concatenate)    (None, 7, 7, 528)     0           leaky_re_lu_500[0][0]
#                                                                    leaky_re_lu_501[0][0]
#                                                                    leaky_re_lu_502[0][0]
#                                                                    conv2d_657[0][0]
# ____________________________________________________________________________________________________
# concatenate_204 (Concatenate)    (None, 7, 7, 528)     0           leaky_re_lu_506[0][0]
#                                                                    leaky_re_lu_507[0][0]
#                                                                    leaky_re_lu_508[0][0]
#                                                                    conv2d_665[0][0]
# ____________________________________________________________________________________________________
# conv2d_658 (Conv2D)              (None, 7, 7, 176)     93104       concatenate_202[0][0]
# ____________________________________________________________________________________________________
# conv2d_659 (Conv2D)              (None, 7, 7, 160)     760480      concatenate_202[0][0]
# ____________________________________________________________________________________________________
# conv2d_660 (Conv2D)              (None, 7, 7, 96)      1267296     concatenate_202[0][0]
# ____________________________________________________________________________________________________
# conv2d_666 (Conv2D)              (None, 7, 7, 176)     93104       concatenate_204[0][0]
# ____________________________________________________________________________________________________
# conv2d_667 (Conv2D)              (None, 7, 7, 160)     760480      concatenate_204[0][0]
# ____________________________________________________________________________________________________
# conv2d_668 (Conv2D)              (None, 7, 7, 96)      1267296     concatenate_204[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_513 (BatchNo (None, 7, 7, 176)     704         conv2d_658[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_514 (BatchNo (None, 7, 7, 160)     640         conv2d_659[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_515 (BatchNo (None, 7, 7, 96)      384         conv2d_660[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_188 (MaxPooling2D) (None, 7, 7, 528)     0           concatenate_202[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_519 (BatchNo (None, 7, 7, 176)     704         conv2d_666[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_520 (BatchNo (None, 7, 7, 160)     640         conv2d_667[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_521 (BatchNo (None, 7, 7, 96)      384         conv2d_668[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_190 (MaxPooling2D) (None, 7, 7, 528)     0           concatenate_204[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_503 (LeakyReLU)      (None, 7, 7, 176)     0           batch_normalization_513[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_504 (LeakyReLU)      (None, 7, 7, 160)     0           batch_normalization_514[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_505 (LeakyReLU)      (None, 7, 7, 96)      0           batch_normalization_515[0][0]
# ____________________________________________________________________________________________________
# conv2d_661 (Conv2D)              (None, 7, 7, 96)      50784       max_pooling2d_188[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_509 (LeakyReLU)      (None, 7, 7, 176)     0           batch_normalization_519[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_510 (LeakyReLU)      (None, 7, 7, 160)     0           batch_normalization_520[0][0]
# ____________________________________________________________________________________________________
# leaky_re_lu_511 (LeakyReLU)      (None, 7, 7, 96)      0           batch_normalization_521[0][0]
# ____________________________________________________________________________________________________
# conv2d_669 (Conv2D)              (None, 7, 7, 96)      50784       max_pooling2d_190[0][0]
# ____________________________________________________________________________________________________
# concatenate_203 (Concatenate)    (None, 7, 7, 528)     0           leaky_re_lu_503[0][0]
#                                                                    leaky_re_lu_504[0][0]
#                                                                    leaky_re_lu_505[0][0]
#                                                                    conv2d_661[0][0]
# ____________________________________________________________________________________________________
# concatenate_205 (Concatenate)    (None, 7, 7, 528)     0           leaky_re_lu_509[0][0]
#                                                                    leaky_re_lu_510[0][0]
#                                                                    leaky_re_lu_511[0][0]
#                                                                    conv2d_669[0][0]
# ____________________________________________________________________________________________________
# concatenate_206 (Concatenate)    (None, 7, 7, 1056)    0           concatenate_203[0][0]
#                                                                    concatenate_205[0][0]
# ____________________________________________________________________________________________________
# average_pooling2d_8 (AveragePool (None, 1, 1, 1056)    0           concatenate_206[0][0]
# ____________________________________________________________________________________________________
# dropout_13 (Dropout)             (None, 1, 1, 1056)    0           average_pooling2d_8[0][0]
# ____________________________________________________________________________________________________
# flatten_13 (Flatten)             (None, 1056)          0           dropout_13[0][0]
# ____________________________________________________________________________________________________
# dense_23 (Dense)                 (None, 10)            10570       flatten_13[0][0]
# ____________________________________________________________________________________________________
# activation_11 (Activation)       (None, 10)            0           dense_23[0][0]
# ====================================================================================================
# Total params: 16,249,922
# Trainable params: 16,238,546
# Non-trainable params: 11,376
# ____________________________________________________________________________________________________

# %%
history = model.fit(aug_train, validation_data=(X_test, y_test_c),
                    steps_per_epoch = len(X_train) // 64, 
                    epochs = n_epochs, callbacks = callback, 
                    verbose = 1)
# Out:
# Epoch 1/50
# 781/781 [==============================] - 105s 125ms/step - loss: 1.6327 - accuracy: 0.4204 - val_loss: 1.1841 - val_accuracy: 0.5950
# Epoch 2/50
# 781/781 [==============================] - 92s 117ms/step - loss: 0.9076 - accuracy: 0.6789 - val_loss: 0.8030 - val_accuracy: 0.7280
# Epoch 3/50
# 781/781 [==============================] - 92s 118ms/step - loss: 0.6948 - accuracy: 0.7595 - val_loss: 0.9446 - val_accuracy: 0.6984
# Epoch 4/50
# 781/781 [==============================] - 92s 118ms/step - loss: 0.5925 - accuracy: 0.7934 - val_loss: 0.9112 - val_accuracy: 0.7099
# Epoch 5/50
# 781/781 [==============================] - 92s 118ms/step - loss: 0.5136 - accuracy: 0.8218 - val_loss: 0.7715 - val_accuracy: 0.7590
# Epoch 6/50
# 781/781 [==============================] - 92s 118ms/step - loss: 0.4463 - accuracy: 0.8468 - val_loss: 0.5781 - val_accuracy: 0.8105
# Epoch 7/50
# 781/781 [==============================] - 92s 118ms/step - loss: 0.4032 - accuracy: 0.8616 - val_loss: 0.5500 - val_accuracy: 0.8178
# Epoch 8/50
# 781/781 [==============================] - 92s 118ms/step - loss: 0.3639 - accuracy: 0.8751 - val_loss: 0.8442 - val_accuracy: 0.7396
# Epoch 9/50
# 781/781 [==============================] - 92s 118ms/step - loss: 0.3331 - accuracy: 0.8855 - val_loss: 0.5590 - val_accuracy: 0.8275
# Epoch 10/50
# 781/781 [==============================] - 92s 117ms/step - loss: 0.2990 - accuracy: 0.8957 - val_loss: 0.5887 - val_accuracy: 0.8216
# Epoch 11/50
# 781/781 [==============================] - 91s 117ms/step - loss: 0.2811 - accuracy: 0.9035 - val_loss: 0.4654 - val_accuracy: 0.8479
# Epoch 12/50
# 781/781 [==============================] - 92s 117ms/step - loss: 0.2515 - accuracy: 0.9134 - val_loss: 0.5439 - val_accuracy: 0.8326
# Epoch 13/50
# 781/781 [==============================] - 92s 117ms/step - loss: 0.2338 - accuracy: 0.9188 - val_loss: 0.4512 - val_accuracy: 0.8537
# Epoch 14/50
# 781/781 [==============================] - 91s 117ms/step - loss: 0.2131 - accuracy: 0.9261 - val_loss: 0.5361 - val_accuracy: 0.8367
# Epoch 15/50
# 781/781 [==============================] - 93s 118ms/step - loss: 0.1910 - accuracy: 0.9337 - val_loss: 0.5283 - val_accuracy: 0.8432
# Epoch 16/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.1819 - accuracy: 0.9378 - val_loss: 0.5031 - val_accuracy: 0.8525
# Epoch 17/50
# 781/781 [==============================] - 93s 118ms/step - loss: 0.1675 - accuracy: 0.9397 - val_loss: 0.4382 - val_accuracy: 0.8705
# Epoch 18/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.1401 - accuracy: 0.9511 - val_loss: 0.4547 - val_accuracy: 0.8618
# Epoch 19/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.1367 - accuracy: 0.9513 - val_loss: 0.5379 - val_accuracy: 0.8555
# Epoch 20/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.1196 - accuracy: 0.9591 - val_loss: 0.4814 - val_accuracy: 0.8657
# Epoch 21/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.1075 - accuracy: 0.9639 - val_loss: 0.3992 - val_accuracy: 0.8885
# Epoch 22/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.1040 - accuracy: 0.9644 - val_loss: 0.4786 - val_accuracy: 0.8734
# Epoch 23/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0899 - accuracy: 0.9683 - val_loss: 0.4392 - val_accuracy: 0.8805
# Epoch 24/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0849 - accuracy: 0.9703 - val_loss: 0.4092 - val_accuracy: 0.8898
# Epoch 25/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0812 - accuracy: 0.9726 - val_loss: 0.3881 - val_accuracy: 0.8924
# Epoch 26/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0714 - accuracy: 0.9752 - val_loss: 0.3883 - val_accuracy: 0.8947
# Epoch 27/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0605 - accuracy: 0.9796 - val_loss: 0.4050 - val_accuracy: 0.8889
# Epoch 28/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0574 - accuracy: 0.9806 - val_loss: 0.4502 - val_accuracy: 0.8822
# Epoch 29/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0519 - accuracy: 0.9834 - val_loss: 0.5465 - val_accuracy: 0.8727
# Epoch 30/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0462 - accuracy: 0.9846 - val_loss: 0.3760 - val_accuracy: 0.9020
# Epoch 31/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0412 - accuracy: 0.9865 - val_loss: 0.4290 - val_accuracy: 0.8970
# Epoch 32/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0383 - accuracy: 0.9879 - val_loss: 0.4788 - val_accuracy: 0.8882
# Epoch 33/50
# 781/781 [==============================] - 92s 118ms/step - loss: 0.0329 - accuracy: 0.9889 - val_loss: 0.4049 - val_accuracy: 0.9029
# Epoch 34/50
# 781/781 [==============================] - 93s 118ms/step - loss: 0.0282 - accuracy: 0.9908 - val_loss: 0.3872 - val_accuracy: 0.9066
# Epoch 35/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0266 - accuracy: 0.9919 - val_loss: 0.4036 - val_accuracy: 0.9024
# Epoch 36/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0225 - accuracy: 0.9925 - val_loss: 0.4295 - val_accuracy: 0.9021
# Epoch 37/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0189 - accuracy: 0.9943 - val_loss: 0.3900 - val_accuracy: 0.9085
# Epoch 38/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0194 - accuracy: 0.9938 - val_loss: 0.3871 - val_accuracy: 0.9096
# Epoch 39/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0182 - accuracy: 0.9946 - val_loss: 0.3715 - val_accuracy: 0.9114
# Epoch 40/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0134 - accuracy: 0.9966 - val_loss: 0.3785 - val_accuracy: 0.9125
# Epoch 41/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0138 - accuracy: 0.9961 - val_loss: 0.3843 - val_accuracy: 0.9122
# Epoch 42/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0122 - accuracy: 0.9967 - val_loss: 0.3831 - val_accuracy: 0.9119
# Epoch 43/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0109 - accuracy: 0.9967 - val_loss: 0.3684 - val_accuracy: 0.9158
# Epoch 44/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0107 - accuracy: 0.9973 - val_loss: 0.3546 - val_accuracy: 0.9178
# Epoch 45/50
# 781/781 [==============================] - 93s 119ms/step - loss: 0.0084 - accuracy: 0.9979 - val_loss: 0.3603 - val_accuracy: 0.9191
# Epoch 46/50
# 781/781 [==============================] - 92s 118ms/step - loss: 0.0086 - accuracy: 0.9981 - val_loss: 0.3674 - val_accuracy: 0.9153
# Epoch 47/50
# 781/781 [==============================] - 92s 118ms/step - loss: 0.0089 - accuracy: 0.9979 - val_loss: 0.3639 - val_accuracy: 0.9169
# Epoch 48/50
# 781/781 [==============================] - 92s 118ms/step - loss: 0.0072 - accuracy: 0.9982 - val_loss: 0.3618 - val_accuracy: 0.9180
# Epoch 49/50
# 781/781 [==============================] - 92s 118ms/step - loss: 0.0071 - accuracy: 0.9984 - val_loss: 0.3602 - val_accuracy: 0.9177
# Epoch 50/50
# 781/781 [==============================] - 92s 118ms/step - loss: 0.0075 - accuracy: 0.9979 - val_loss: 0.3596 - val_accuracy: 0.9172

# %%
PlotModelEval(model, history, X_test, y_test, cifar_labels)

# %% [markdown]
# **Don't forget to save your model!**

# %%
model.save("CompetionModel_" + GroupName + ".h5")
